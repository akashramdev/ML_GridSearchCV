# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import display
pd.options.display.max_columns = None
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn import metrics
from sklearn.preprocessing import MinMaxScaler, StandardScaler, LabelEncoder
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn import svm, datasets

# %%
df = pd.read_csv('BankChurners.csv')

# %%
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# 0              39                         5                       1
# 1              44                         6                       1
# 2              36                         4                       1
# 3              34                         3                       4
# 4              21                         5                       1
#
#    Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0                      3       12691.0                  777          11914.0
# 1                      2        8256.0                  864           7392.0
# 2                      0        3418.0                    0           3418.0
# 3                      1        3313.0                 2517            796.0
# 4                      0        4716.0                    0           4716.0
#
#    Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  \
# 0                 1.335             1144              42                1.625
# 1                 1.541             1291              33                3.714
# 2                 2.594             1887              20                2.333
# 3                 1.405             1171              20                2.333
# 4                 2.175              816              28                2.500
#
#    Avg_Utilization_Ratio Churned or not
# 0                  0.061        Churned
# 1                  0.105        Churned
# 2                  0.000        Churned
# 3                  0.760        Churned
# 4                  0.000        Churned

# %%
df.shape
# Out:
# (10127, 22)

# %%
df = df.drop('CLIENTNUM',axis=1)

# %%
df.head()
# Out:
#       Attrition_Flag  Customer_Age Gender  Dependent_count Education_Level  \
# 0  Existing Customer            45      M                3     High School
# 1  Existing Customer            49      F                5        Graduate
# 2  Existing Customer            51      M                3        Graduate
# 3  Existing Customer            40      F                4     High School
# 4  Existing Customer            40      M                3      Uneducated
#
#   Marital_Status Income_Category Card_Category  Months_on_book  \
# 0        Married     $60K - $80K          Blue              39
# 1         Single  Less than $40K          Blue              44
# 2        Married    $80K - $120K          Blue              36
# 3        Unknown  Less than $40K          Blue              34
# 4        Married     $60K - $80K          Blue              21
#
#    Total_Relationship_Count  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0                         5                       1                      3
# 1                         6                       1                      2
# 2                         4                       1                      0
# 3                         3                       4                      1
# 4                         5                       1                      0
#
#    Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  \
# 0       12691.0                  777          11914.0                 1.335
# 1        8256.0                  864           7392.0                 1.541
# 2        3418.0                    0           3418.0                 2.594
# 3        3313.0                 2517            796.0                 1.405
# 4        4716.0                    0           4716.0                 2.175
#
#    Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  \
# 0             1144              42                1.625
# 1             1291              33                3.714
# 2             1887              20                2.333
# 3             1171              20                2.333
# 4              816              28                2.500
#
#    Avg_Utilization_Ratio Churned or not
# 0                  0.061        Churned
# 1                  0.105        Churned
# 2                  0.000        Churned
# 3                  0.760        Churned
# 4                  0.000        Churned

# %%
objList = df.select_dtypes(include = "object").columns
print (objList)
# Out:
# Index(['Attrition_Flag', 'Gender', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Churned or not'],
#       dtype='object')

# %%
#Label Encoding for object to numeric conversion
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

for feat in objList:
    df[feat] = le.fit_transform(df[feat].astype(str))

print (df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Attrition_Flag            10127 non-null  int32
#  1   Customer_Age              10127 non-null  int64
#  2   Gender                    10127 non-null  int32
#  3   Dependent_count           10127 non-null  int64
#  4   Education_Level           10127 non-null  int32
#  5   Marital_Status            10127 non-null  int32
#  6   Income_Category           10127 non-null  int32
#  7   Card_Category             10127 non-null  int32
#  8   Months_on_book            10127 non-null  int64
#  9   Total_Relationship_Count  10127 non-null  int64
#  10  Months_Inactive_12_mon    10127 non-null  int64
#  11  Contacts_Count_12_mon     10127 non-null  int64
#  12  Credit_Limit              10127 non-null  float64
#  13  Total_Revolving_Bal       10127 non-null  int64
#  14  Avg_Open_To_Buy           10127 non-null  float64
#  15  Total_Amt_Chng_Q4_Q1      10127 non-null  float64
#  16  Total_Trans_Amt           10127 non-null  int64
#  17  Total_Trans_Ct            10127 non-null  int64
#  18  Total_Ct_Chng_Q4_Q1       10127 non-null  float64
#  19  Avg_Utilization_Ratio     10127 non-null  float64
#  20  Churned or not            10127 non-null  int32
# dtypes: float64(5), int32(7), int64(9)
# memory usage: 1.4 MB
# None

# %%
#separate the other attributes from the predicting attribute
X = df.drop('Churned or not',axis=1)
#separte the predicting attribute into Y for model training 
y = df['Churned or not']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X)
X = scaler.transform(X)

# %%
from sklearn.decomposition import PCA
pca = PCA(0.95)
#pca=PCA(n_components=15)

# %%
pca.fit(X) 
X_pca=pca.transform(X) 
#let's check the shape of X_pca array
print("shape of X_pca", X_pca.shape)
# Out:
# shape of X_pca (10127, 15)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.1558432 , 0.11497033, 0.09075808, 0.0848604 , 0.06559919,
#        0.05932595, 0.05257712, 0.05098808, 0.04982215, 0.04903893,
#        0.04653094, 0.04380004, 0.0322129 , 0.03031867, 0.02494835])

# %%
X_recovered = pca.inverse_transform(X_pca)

# %%
X_recovered.shape
# Out:
# (10127, 20)

# %%
X_recovered
# Out:
# array([[ 0.47695603,  0.10960947,  0.87782941, ..., -1.05018613,
#          3.82165824, -0.75173546],
#        [ 0.40433686,  0.74586177, -0.86117057, ..., -1.20881616,
#         12.60251589, -0.32939505],
#        [ 0.38265576,  0.25174951,  0.35543414, ..., -1.60242151,
#          6.80645609, -0.97843946],
#        ...,
#        [-2.48291797, -0.13030178, -0.80421918, ...,  0.4565013 ,
#          0.46237604, -0.94133017],
#        [-2.37261456, -1.0097841 ,  0.89143415, ...,  0.28671486,
#          0.02759684, -0.97714288],
#        [-2.42493313, -0.88654739, -1.43385777, ...,  0.43789584,
#         -0.26112192,  0.47848503]])

# %%
# importing train_test_split from sklearn
from sklearn.model_selection import train_test_split
# splitting the data
x_train, x_test, y_train, y_test = train_test_split(X_pca, y, test_size = 0.2, random_state = 100)

# %%
x_train.shape
# Out:
# (8101, 15)

# %%
from sklearn.svm import SVC
svm = SVC()
svm.fit(x_train,y_train)
# Out:
# SVC()

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'C':[0.1,1,10,100], 'gamma':[1,0.1,0.01,0.001], 'kernel':['linear', 'poly', 'rbf', 'sigmoid']}

grid = GridSearchCV(SVC(), param_grid, refit = True, verbose=3)
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 64 candidates, totalling 320 fits
# [CV 1/5] END ..................C=0.1, gamma=1, kernel=linear; total time=   0.0s
# [CV 2/5] END ..................C=0.1, gamma=1, kernel=linear; total time=   0.0s
# [CV 3/5] END ..................C=0.1, gamma=1, kernel=linear; total time=   0.0s
# [CV 4/5] END ..................C=0.1, gamma=1, kernel=linear; total time=   0.0s
# [CV 5/5] END ..................C=0.1, gamma=1, kernel=linear; total time=   0.0s
# [CV 1/5] END ....................C=0.1, gamma=1, kernel=poly; total time=   0.1s
# [CV 2/5] END ....................C=0.1, gamma=1, kernel=poly; total time=   0.0s
# [CV 3/5] END ....................C=0.1, gamma=1, kernel=poly; total time=   0.1s
# [CV 4/5] END ....................C=0.1, gamma=1, kernel=poly; total time=   0.0s
# [CV 5/5] END ....................C=0.1, gamma=1, kernel=poly; total time=   0.0s
# [CV 1/5] END .....................C=0.1, gamma=1, kernel=rbf; total time=   2.6s
# [CV 2/5] END .....................C=0.1, gamma=1, kernel=rbf; total time=   2.6s
# [CV 3/5] END .....................C=0.1, gamma=1, kernel=rbf; total time=   2.7s
# [CV 4/5] END .....................C=0.1, gamma=1, kernel=rbf; total time=   2.6s
# [CV 5/5] END .....................C=0.1, gamma=1, kernel=rbf; total time=   2.6s
# [CV 1/5] END .................C=0.1, gamma=1, kernel=sigmoid; total time=   0.1s
# [CV 2/5] END .................C=0.1, gamma=1, kernel=sigmoid; total time=   0.1s
# [CV 3/5] END .................C=0.1, gamma=1, kernel=sigmoid; total time=   0.1s
# [CV 4/5] END .................C=0.1, gamma=1, kernel=sigmoid; total time=   0.1s
# [CV 5/5] END .................C=0.1, gamma=1, kernel=sigmoid; total time=   0.1s
# [CV 1/5] END ................C=0.1, gamma=0.1, kernel=linear; total time=   0.0s
# [CV 2/5] END ................C=0.1, gamma=0.1, kernel=linear; total time=   0.0s
# [CV 3/5] END ................C=0.1, gamma=0.1, kernel=linear; total time=   0.0s
# [CV 4/5] END ................C=0.1, gamma=0.1, kernel=linear; total time=   0.0s
# [CV 5/5] END ................C=0.1, gamma=0.1, kernel=linear; total time=   0.0s
# [CV 1/5] END ..................C=0.1, gamma=0.1, kernel=poly; total time=   0.0s
# [CV 2/5] END ..................C=0.1, gamma=0.1, kernel=poly; total time=   0.0s
# [CV 3/5] END ..................C=0.1, gamma=0.1, kernel=poly; total time=   0.0s
# [CV 4/5] END ..................C=0.1, gamma=0.1, kernel=poly; total time=   0.0s
# [CV 5/5] END ..................C=0.1, gamma=0.1, kernel=poly; total time=   0.0s
# [CV 1/5] END ...................C=0.1, gamma=0.1, kernel=rbf; total time=   0.5s
# [CV 2/5] END ...................C=0.1, gamma=0.1, kernel=rbf; total time=   0.5s
# [CV 3/5] END ...................C=0.1, gamma=0.1, kernel=rbf; total time=   0.6s
# [CV 4/5] END ...................C=0.1, gamma=0.1, kernel=rbf; total time=   0.5s
# [CV 5/5] END ...................C=0.1, gamma=0.1, kernel=rbf; total time=   0.5s
# [CV 1/5] END ...............C=0.1, gamma=0.1, kernel=sigmoid; total time=   0.0s
# [CV 2/5] END ...............C=0.1, gamma=0.1, kernel=sigmoid; total time=   0.0s
# [CV 3/5] END ...............C=0.1, gamma=0.1, kernel=sigmoid; total time=   0.0s
# [CV 4/5] END ...............C=0.1, gamma=0.1, kernel=sigmoid; total time=   0.1s
# [CV 5/5] END ...............C=0.1, gamma=0.1, kernel=sigmoid; total time=   0.1s
# [CV 1/5] END ...............C=0.1, gamma=0.01, kernel=linear; total time=   0.0s
# [CV 2/5] END ...............C=0.1, gamma=0.01, kernel=linear; total time=   0.0s
# [CV 3/5] END ...............C=0.1, gamma=0.01, kernel=linear; total time=   0.0s
# [CV 4/5] END ...............C=0.1, gamma=0.01, kernel=linear; total time=   0.0s
# [CV 5/5] END ...............C=0.1, gamma=0.01, kernel=linear; total time=   0.0s
# [CV 1/5] END .................C=0.1, gamma=0.01, kernel=poly; total time=   0.4s
# [CV 2/5] END .................C=0.1, gamma=0.01, kernel=poly; total time=   0.5s
# [CV 3/5] END .................C=0.1, gamma=0.01, kernel=poly; total time=   0.4s
# [CV 4/5] END .................C=0.1, gamma=0.01, kernel=poly; total time=   0.5s
# [CV 5/5] END .................C=0.1, gamma=0.01, kernel=poly; total time=   0.5s
# [CV 1/5] END ..................C=0.1, gamma=0.01, kernel=rbf; total time=   0.2s
# [CV 2/5] END ..................C=0.1, gamma=0.01, kernel=rbf; total time=   0.2s
# [CV 3/5] END ..................C=0.1, gamma=0.01, kernel=rbf; total time=   0.2s
# [CV 4/5] END ..................C=0.1, gamma=0.01, kernel=rbf; total time=   0.2s
# [CV 5/5] END ..................C=0.1, gamma=0.01, kernel=rbf; total time=   0.1s
# [CV 1/5] END ..............C=0.1, gamma=0.01, kernel=sigmoid; total time=   0.2s
# [CV 2/5] END ..............C=0.1, gamma=0.01, kernel=sigmoid; total time=   0.2s
# [CV 3/5] END ..............C=0.1, gamma=0.01, kernel=sigmoid; total time=   0.2s
# [CV 4/5] END ..............C=0.1, gamma=0.01, kernel=sigmoid; total time=   0.2s
# [CV 5/5] END ..............C=0.1, gamma=0.01, kernel=sigmoid; total time=   0.2s
# [CV 1/5] END ..............C=0.1, gamma=0.001, kernel=linear; total time=   0.0s
# [CV 2/5] END ..............C=0.1, gamma=0.001, kernel=linear; total time=   0.0s
# [CV 3/5] END ..............C=0.1, gamma=0.001, kernel=linear; total time=   0.0s
# [CV 4/5] END ..............C=0.1, gamma=0.001, kernel=linear; total time=   0.0s
# [CV 5/5] END ..............C=0.1, gamma=0.001, kernel=linear; total time=   0.0s
# [CV 1/5] END ................C=0.1, gamma=0.001, kernel=poly; total time=   0.4s
# [CV 2/5] END ................C=0.1, gamma=0.001, kernel=poly; total time=   0.4s
# [CV 3/5] END ................C=0.1, gamma=0.001, kernel=poly; total time=   0.4s
# [CV 4/5] END ................C=0.1, gamma=0.001, kernel=poly; total time=   0.5s
# [CV 5/5] END ................C=0.1, gamma=0.001, kernel=poly; total time=   0.5s
# [CV 1/5] END .................C=0.1, gamma=0.001, kernel=rbf; total time=   0.8s
# [CV 2/5] END .................C=0.1, gamma=0.001, kernel=rbf; total time=   0.9s
# [CV 3/5] END .................C=0.1, gamma=0.001, kernel=rbf; total time=   0.8s
# [CV 4/5] END .................C=0.1, gamma=0.001, kernel=rbf; total time=   0.8s
# [CV 5/5] END .................C=0.1, gamma=0.001, kernel=rbf; total time=   0.8s
# [CV 1/5] END .............C=0.1, gamma=0.001, kernel=sigmoid; total time=   0.8s
# [CV 2/5] END .............C=0.1, gamma=0.001, kernel=sigmoid; total time=   0.7s
# [CV 3/5] END .............C=0.1, gamma=0.001, kernel=sigmoid; total time=   0.8s
# [CV 4/5] END .............C=0.1, gamma=0.001, kernel=sigmoid; total time=   0.7s
# [CV 5/5] END .............C=0.1, gamma=0.001, kernel=sigmoid; total time=   0.7s
# [CV 1/5] END ....................C=1, gamma=1, kernel=linear; total time=   0.0s
# [CV 2/5] END ....................C=1, gamma=1, kernel=linear; total time=   0.0s
# [CV 3/5] END ....................C=1, gamma=1, kernel=linear; total time=   0.0s
# [CV 4/5] END ....................C=1, gamma=1, kernel=linear; total time=   0.0s
# [CV 5/5] END ....................C=1, gamma=1, kernel=linear; total time=   0.0s
# [CV 1/5] END ......................C=1, gamma=1, kernel=poly; total time=   0.0s
# [CV 2/5] END ......................C=1, gamma=1, kernel=poly; total time=   0.0s
# [CV 3/5] END ......................C=1, gamma=1, kernel=poly; total time=   0.0s
# [CV 4/5] END ......................C=1, gamma=1, kernel=poly; total time=   0.0s
# [CV 5/5] END ......................C=1, gamma=1, kernel=poly; total time=   0.1s
# [CV 1/5] END .......................C=1, gamma=1, kernel=rbf; total time=   2.7s
# [CV 2/5] END .......................C=1, gamma=1, kernel=rbf; total time=   2.8s
# [CV 3/5] END .......................C=1, gamma=1, kernel=rbf; total time=   2.9s
# [CV 4/5] END .......................C=1, gamma=1, kernel=rbf; total time=   2.8s
# [CV 5/5] END .......................C=1, gamma=1, kernel=rbf; total time=   2.7s
# [CV 1/5] END ...................C=1, gamma=1, kernel=sigmoid; total time=   0.1s
# [CV 2/5] END ...................C=1, gamma=1, kernel=sigmoid; total time=   0.1s
# [CV 3/5] END ...................C=1, gamma=1, kernel=sigmoid; total time=   0.1s
# [CV 4/5] END ...................C=1, gamma=1, kernel=sigmoid; total time=   0.1s
# [CV 5/5] END ...................C=1, gamma=1, kernel=sigmoid; total time=   0.1s
# [CV 1/5] END ..................C=1, gamma=0.1, kernel=linear; total time=   0.0s
# [CV 2/5] END ..................C=1, gamma=0.1, kernel=linear; total time=   0.0s
# [CV 3/5] END ..................C=1, gamma=0.1, kernel=linear; total time=   0.0s
# [CV 4/5] END ..................C=1, gamma=0.1, kernel=linear; total time=   0.0s
# [CV 5/5] END ..................C=1, gamma=0.1, kernel=linear; total time=   0.0s
# [CV 1/5] END ....................C=1, gamma=0.1, kernel=poly; total time=   0.1s
# [CV 2/5] END ....................C=1, gamma=0.1, kernel=poly; total time=   0.0s
# [CV 3/5] END ....................C=1, gamma=0.1, kernel=poly; total time=   0.0s
# [CV 4/5] END ....................C=1, gamma=0.1, kernel=poly; total time=   0.0s
# [CV 5/5] END ....................C=1, gamma=0.1, kernel=poly; total time=   0.0s
# [CV 1/5] END .....................C=1, gamma=0.1, kernel=rbf; total time=   0.3s
# [CV 2/5] END .....................C=1, gamma=0.1, kernel=rbf; total time=   0.3s
# [CV 3/5] END .....................C=1, gamma=0.1, kernel=rbf; total time=   0.3s
# [CV 4/5] END .....................C=1, gamma=0.1, kernel=rbf; total time=   0.3s
# [CV 5/5] END .....................C=1, gamma=0.1, kernel=rbf; total time=   0.3s
# [CV 1/5] END .................C=1, gamma=0.1, kernel=sigmoid; total time=   0.0s
# [CV 2/5] END .................C=1, gamma=0.1, kernel=sigmoid; total time=   0.0s
# [CV 3/5] END .................C=1, gamma=0.1, kernel=sigmoid; total time=   0.0s
# [CV 4/5] END .................C=1, gamma=0.1, kernel=sigmoid; total time=   0.0s
# [CV 5/5] END .................C=1, gamma=0.1, kernel=sigmoid; total time=   0.0s
# [CV 1/5] END .................C=1, gamma=0.01, kernel=linear; total time=   0.0s
# [CV 2/5] END .................C=1, gamma=0.01, kernel=linear; total time=   0.0s
# [CV 3/5] END .................C=1, gamma=0.01, kernel=linear; total time=   0.0s
# [CV 4/5] END .................C=1, gamma=0.01, kernel=linear; total time=   0.0s
# [CV 5/5] END .................C=1, gamma=0.01, kernel=linear; total time=   0.0s
# [CV 1/5] END ...................C=1, gamma=0.01, kernel=poly; total time=   0.5s
# [CV 2/5] END ...................C=1, gamma=0.01, kernel=poly; total time=   0.4s
# [CV 3/5] END ...................C=1, gamma=0.01, kernel=poly; total time=   0.4s
# [CV 4/5] END ...................C=1, gamma=0.01, kernel=poly; total time=   0.5s
# [CV 5/5] END ...................C=1, gamma=0.01, kernel=poly; total time=   0.4s
# [CV 1/5] END ....................C=1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 2/5] END ....................C=1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 3/5] END ....................C=1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 4/5] END ....................C=1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 5/5] END ....................C=1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 1/5] END ................C=1, gamma=0.01, kernel=sigmoid; total time=   0.0s
# [CV 2/5] END ................C=1, gamma=0.01, kernel=sigmoid; total time=   0.0s
# [CV 3/5] END ................C=1, gamma=0.01, kernel=sigmoid; total time=   0.0s
# [CV 4/5] END ................C=1, gamma=0.01, kernel=sigmoid; total time=   0.0s
# [CV 5/5] END ................C=1, gamma=0.01, kernel=sigmoid; total time=   0.0s
# [CV 1/5] END ................C=1, gamma=0.001, kernel=linear; total time=   0.0s
# [CV 2/5] END ................C=1, gamma=0.001, kernel=linear; total time=   0.0s
# [CV 3/5] END ................C=1, gamma=0.001, kernel=linear; total time=   0.0s
# [CV 4/5] END ................C=1, gamma=0.001, kernel=linear; total time=   0.0s
# [CV 5/5] END ................C=1, gamma=0.001, kernel=linear; total time=   0.0s
# [CV 1/5] END ..................C=1, gamma=0.001, kernel=poly; total time=   0.4s
# [CV 2/5] END ..................C=1, gamma=0.001, kernel=poly; total time=   0.4s
# [CV 3/5] END ..................C=1, gamma=0.001, kernel=poly; total time=   0.4s
# [CV 4/5] END ..................C=1, gamma=0.001, kernel=poly; total time=   0.4s
# [CV 5/5] END ..................C=1, gamma=0.001, kernel=poly; total time=   0.4s
# [CV 1/5] END ...................C=1, gamma=0.001, kernel=rbf; total time=   0.1s
# [CV 2/5] END ...................C=1, gamma=0.001, kernel=rbf; total time=   0.1s
# [CV 3/5] END ...................C=1, gamma=0.001, kernel=rbf; total time=   0.1s
# [CV 4/5] END ...................C=1, gamma=0.001, kernel=rbf; total time=   0.1s
# [CV 5/5] END ...................C=1, gamma=0.001, kernel=rbf; total time=   0.1s
# [CV 1/5] END ...............C=1, gamma=0.001, kernel=sigmoid; total time=   0.2s
# [CV 2/5] END ...............C=1, gamma=0.001, kernel=sigmoid; total time=   0.2s
# [CV 3/5] END ...............C=1, gamma=0.001, kernel=sigmoid; total time=   0.2s
# [CV 4/5] END ...............C=1, gamma=0.001, kernel=sigmoid; total time=   0.2s
# [CV 5/5] END ...............C=1, gamma=0.001, kernel=sigmoid; total time=   0.3s
# [CV 1/5] END ...................C=10, gamma=1, kernel=linear; total time=   0.0s
# [CV 2/5] END ...................C=10, gamma=1, kernel=linear; total time=   0.0s
# [CV 3/5] END ...................C=10, gamma=1, kernel=linear; total time=   0.0s
# [CV 4/5] END ...................C=10, gamma=1, kernel=linear; total time=   0.0s
# [CV 5/5] END ...................C=10, gamma=1, kernel=linear; total time=   0.0s
# [CV 1/5] END .....................C=10, gamma=1, kernel=poly; total time=   0.0s
# [CV 2/5] END .....................C=10, gamma=1, kernel=poly; total time=   0.0s
# [CV 3/5] END .....................C=10, gamma=1, kernel=poly; total time=   0.0s
# [CV 4/5] END .....................C=10, gamma=1, kernel=poly; total time=   0.0s
# [CV 5/5] END .....................C=10, gamma=1, kernel=poly; total time=   0.0s
# [CV 1/5] END ......................C=10, gamma=1, kernel=rbf; total time=   2.9s
# [CV 2/5] END ......................C=10, gamma=1, kernel=rbf; total time=   2.9s
# [CV 3/5] END ......................C=10, gamma=1, kernel=rbf; total time=   2.9s
# [CV 4/5] END ......................C=10, gamma=1, kernel=rbf; total time=   2.9s
# [CV 5/5] END ......................C=10, gamma=1, kernel=rbf; total time=   2.8s
# [CV 1/5] END ..................C=10, gamma=1, kernel=sigmoid; total time=   0.1s
# [CV 2/5] END ..................C=10, gamma=1, kernel=sigmoid; total time=   0.0s
# [CV 3/5] END ..................C=10, gamma=1, kernel=sigmoid; total time=   0.1s
# [CV 4/5] END ..................C=10, gamma=1, kernel=sigmoid; total time=   0.1s
# [CV 5/5] END ..................C=10, gamma=1, kernel=sigmoid; total time=   0.1s
# [CV 1/5] END .................C=10, gamma=0.1, kernel=linear; total time=   0.0s
# [CV 2/5] END .................C=10, gamma=0.1, kernel=linear; total time=   0.0s
# [CV 3/5] END .................C=10, gamma=0.1, kernel=linear; total time=   0.0s
# [CV 4/5] END .................C=10, gamma=0.1, kernel=linear; total time=   0.0s
# [CV 5/5] END .................C=10, gamma=0.1, kernel=linear; total time=   0.0s
# [CV 1/5] END ...................C=10, gamma=0.1, kernel=poly; total time=   0.1s
# [CV 2/5] END ...................C=10, gamma=0.1, kernel=poly; total time=   0.0s
# [CV 3/5] END ...................C=10, gamma=0.1, kernel=poly; total time=   0.0s
# [CV 4/5] END ...................C=10, gamma=0.1, kernel=poly; total time=   0.0s
# [CV 5/5] END ...................C=10, gamma=0.1, kernel=poly; total time=   0.0s
# [CV 1/5] END ....................C=10, gamma=0.1, kernel=rbf; total time=   0.3s
# [CV 2/5] END ....................C=10, gamma=0.1, kernel=rbf; total time=   0.3s
# [CV 3/5] END ....................C=10, gamma=0.1, kernel=rbf; total time=   0.3s
# [CV 4/5] END ....................C=10, gamma=0.1, kernel=rbf; total time=   0.3s
# [CV 5/5] END ....................C=10, gamma=0.1, kernel=rbf; total time=   0.3s
# [CV 1/5] END ................C=10, gamma=0.1, kernel=sigmoid; total time=   0.0s
# [CV 2/5] END ................C=10, gamma=0.1, kernel=sigmoid; total time=   0.0s
# [CV 3/5] END ................C=10, gamma=0.1, kernel=sigmoid; total time=   0.0s
# [CV 4/5] END ................C=10, gamma=0.1, kernel=sigmoid; total time=   0.0s
# [CV 5/5] END ................C=10, gamma=0.1, kernel=sigmoid; total time=   0.0s
# [CV 1/5] END ................C=10, gamma=0.01, kernel=linear; total time=   0.0s
# [CV 2/5] END ................C=10, gamma=0.01, kernel=linear; total time=   0.0s
# [CV 3/5] END ................C=10, gamma=0.01, kernel=linear; total time=   0.0s
# [CV 4/5] END ................C=10, gamma=0.01, kernel=linear; total time=   0.0s
# [CV 5/5] END ................C=10, gamma=0.01, kernel=linear; total time=   0.0s
# [CV 1/5] END ..................C=10, gamma=0.01, kernel=poly; total time=   0.2s
# [CV 2/5] END ..................C=10, gamma=0.01, kernel=poly; total time=   0.2s
# [CV 3/5] END ..................C=10, gamma=0.01, kernel=poly; total time=   0.4s
# [CV 4/5] END ..................C=10, gamma=0.01, kernel=poly; total time=   0.2s
# [CV 5/5] END ..................C=10, gamma=0.01, kernel=poly; total time=   0.1s
# [CV 1/5] END ...................C=10, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 2/5] END ...................C=10, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 3/5] END ...................C=10, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 4/5] END ...................C=10, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 5/5] END ...................C=10, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 1/5] END ...............C=10, gamma=0.01, kernel=sigmoid; total time=   0.0s
# [CV 2/5] END ...............C=10, gamma=0.01, kernel=sigmoid; total time=   0.0s
# [CV 3/5] END ...............C=10, gamma=0.01, kernel=sigmoid; total time=   0.0s
# [CV 4/5] END ...............C=10, gamma=0.01, kernel=sigmoid; total time=   0.0s
# [CV 5/5] END ...............C=10, gamma=0.01, kernel=sigmoid; total time=   0.0s
# [CV 1/5] END ...............C=10, gamma=0.001, kernel=linear; total time=   0.0s
# [CV 2/5] END ...............C=10, gamma=0.001, kernel=linear; total time=   0.0s
# [CV 3/5] END ...............C=10, gamma=0.001, kernel=linear; total time=   0.0s
# [CV 4/5] END ...............C=10, gamma=0.001, kernel=linear; total time=   0.0s
# [CV 5/5] END ...............C=10, gamma=0.001, kernel=linear; total time=   0.0s
# [CV 1/5] END .................C=10, gamma=0.001, kernel=poly; total time=   0.6s
# [CV 2/5] END .................C=10, gamma=0.001, kernel=poly; total time=   0.4s
# [CV 3/5] END .................C=10, gamma=0.001, kernel=poly; total time=   0.4s
# [CV 4/5] END .................C=10, gamma=0.001, kernel=poly; total time=   0.5s
# [CV 5/5] END .................C=10, gamma=0.001, kernel=poly; total time=   0.5s
# [CV 1/5] END ..................C=10, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV 2/5] END ..................C=10, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV 3/5] END ..................C=10, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV 4/5] END ..................C=10, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV 5/5] END ..................C=10, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV 1/5] END ..............C=10, gamma=0.001, kernel=sigmoid; total time=   0.0s
# [CV 2/5] END ..............C=10, gamma=0.001, kernel=sigmoid; total time=   0.0s
# [CV 3/5] END ..............C=10, gamma=0.001, kernel=sigmoid; total time=   0.0s
# [CV 4/5] END ..............C=10, gamma=0.001, kernel=sigmoid; total time=   0.0s
# [CV 5/5] END ..............C=10, gamma=0.001, kernel=sigmoid; total time=   0.0s
# [CV 1/5] END ..................C=100, gamma=1, kernel=linear; total time=   0.0s
# [CV 2/5] END ..................C=100, gamma=1, kernel=linear; total time=   0.0s
# [CV 3/5] END ..................C=100, gamma=1, kernel=linear; total time=   0.0s
# [CV 4/5] END ..................C=100, gamma=1, kernel=linear; total time=   0.0s
# [CV 5/5] END ..................C=100, gamma=1, kernel=linear; total time=   0.0s
# [CV 1/5] END ....................C=100, gamma=1, kernel=poly; total time=   0.0s
# [CV 2/5] END ....................C=100, gamma=1, kernel=poly; total time=   0.0s
# [CV 3/5] END ....................C=100, gamma=1, kernel=poly; total time=   0.0s
# [CV 4/5] END ....................C=100, gamma=1, kernel=poly; total time=   0.0s
# [CV 5/5] END ....................C=100, gamma=1, kernel=poly; total time=   0.0s
# [CV 1/5] END .....................C=100, gamma=1, kernel=rbf; total time=   2.9s
# [CV 2/5] END .....................C=100, gamma=1, kernel=rbf; total time=   2.9s
# [CV 3/5] END .....................C=100, gamma=1, kernel=rbf; total time=   2.9s
# [CV 4/5] END .....................C=100, gamma=1, kernel=rbf; total time=   3.9s
# [CV 5/5] END .....................C=100, gamma=1, kernel=rbf; total time=   4.5s
# [CV 1/5] END .................C=100, gamma=1, kernel=sigmoid; total time=   0.1s
# [CV 2/5] END .................C=100, gamma=1, kernel=sigmoid; total time=   0.1s
# [CV 3/5] END .................C=100, gamma=1, kernel=sigmoid; total time=   0.1s
# [CV 4/5] END .................C=100, gamma=1, kernel=sigmoid; total time=   0.1s
# [CV 5/5] END .................C=100, gamma=1, kernel=sigmoid; total time=   0.1s
# [CV 1/5] END ................C=100, gamma=0.1, kernel=linear; total time=   0.0s
# [CV 2/5] END ................C=100, gamma=0.1, kernel=linear; total time=   0.0s
# [CV 3/5] END ................C=100, gamma=0.1, kernel=linear; total time=   0.0s
# [CV 4/5] END ................C=100, gamma=0.1, kernel=linear; total time=   0.0s
# [CV 5/5] END ................C=100, gamma=0.1, kernel=linear; total time=   0.0s
# [CV 1/5] END ..................C=100, gamma=0.1, kernel=poly; total time=   0.0s
# [CV 2/5] END ..................C=100, gamma=0.1, kernel=poly; total time=   0.1s
# [CV 3/5] END ..................C=100, gamma=0.1, kernel=poly; total time=   0.0s
# [CV 4/5] END ..................C=100, gamma=0.1, kernel=poly; total time=   0.0s
# [CV 5/5] END ..................C=100, gamma=0.1, kernel=poly; total time=   0.0s
# [CV 1/5] END ...................C=100, gamma=0.1, kernel=rbf; total time=   0.3s
# [CV 2/5] END ...................C=100, gamma=0.1, kernel=rbf; total time=   0.3s
# [CV 3/5] END ...................C=100, gamma=0.1, kernel=rbf; total time=   0.4s
# [CV 4/5] END ...................C=100, gamma=0.1, kernel=rbf; total time=   0.3s
# [CV 5/5] END ...................C=100, gamma=0.1, kernel=rbf; total time=   0.3s
# [CV 1/5] END ...............C=100, gamma=0.1, kernel=sigmoid; total time=   0.0s
# [CV 2/5] END ...............C=100, gamma=0.1, kernel=sigmoid; total time=   0.0s
# [CV 3/5] END ...............C=100, gamma=0.1, kernel=sigmoid; total time=   0.0s
# [CV 4/5] END ...............C=100, gamma=0.1, kernel=sigmoid; total time=   0.0s
# [CV 5/5] END ...............C=100, gamma=0.1, kernel=sigmoid; total time=   0.0s
# [CV 1/5] END ...............C=100, gamma=0.01, kernel=linear; total time=   0.0s
# [CV 2/5] END ...............C=100, gamma=0.01, kernel=linear; total time=   0.0s
# [CV 3/5] END ...............C=100, gamma=0.01, kernel=linear; total time=   0.0s
# [CV 4/5] END ...............C=100, gamma=0.01, kernel=linear; total time=   0.0s
# [CV 5/5] END ...............C=100, gamma=0.01, kernel=linear; total time=   0.0s
# [CV 1/5] END .................C=100, gamma=0.01, kernel=poly; total time=   0.0s
# [CV 2/5] END .................C=100, gamma=0.01, kernel=poly; total time=   0.0s
# [CV 3/5] END .................C=100, gamma=0.01, kernel=poly; total time=   0.0s
# [CV 4/5] END .................C=100, gamma=0.01, kernel=poly; total time=   0.0s
# [CV 5/5] END .................C=100, gamma=0.01, kernel=poly; total time=   0.0s
# [CV 1/5] END ..................C=100, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 2/5] END ..................C=100, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 3/5] END ..................C=100, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 4/5] END ..................C=100, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 5/5] END ..................C=100, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 1/5] END ..............C=100, gamma=0.01, kernel=sigmoid; total time=   0.0s
# [CV 2/5] END ..............C=100, gamma=0.01, kernel=sigmoid; total time=   0.0s
# [CV 3/5] END ..............C=100, gamma=0.01, kernel=sigmoid; total time=   0.0s
# [CV 4/5] END ..............C=100, gamma=0.01, kernel=sigmoid; total time=   0.0s
# [CV 5/5] END ..............C=100, gamma=0.01, kernel=sigmoid; total time=   0.0s
# [CV 1/5] END ..............C=100, gamma=0.001, kernel=linear; total time=   0.0s
# [CV 2/5] END ..............C=100, gamma=0.001, kernel=linear; total time=   0.0s
# [CV 3/5] END ..............C=100, gamma=0.001, kernel=linear; total time=   0.0s
# [CV 4/5] END ..............C=100, gamma=0.001, kernel=linear; total time=   0.0s
# [CV 5/5] END ..............C=100, gamma=0.001, kernel=linear; total time=   0.0s
# [CV 1/5] END ................C=100, gamma=0.001, kernel=poly; total time=   0.5s
# [CV 2/5] END ................C=100, gamma=0.001, kernel=poly; total time=   0.4s
# [CV 3/5] END ................C=100, gamma=0.001, kernel=poly; total time=   0.4s
# [CV 4/5] END ................C=100, gamma=0.001, kernel=poly; total time=   0.4s
# [CV 5/5] END ................C=100, gamma=0.001, kernel=poly; total time=   0.4s
# [CV 1/5] END .................C=100, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV 2/5] END .................C=100, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV 3/5] END .................C=100, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV 4/5] END .................C=100, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV 5/5] END .................C=100, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV 1/5] END .............C=100, gamma=0.001, kernel=sigmoid; total time=   0.0s
# [CV 2/5] END .............C=100, gamma=0.001, kernel=sigmoid; total time=   0.0s
# [CV 3/5] END .............C=100, gamma=0.001, kernel=sigmoid; total time=   0.0s
# [CV 4/5] END .............C=100, gamma=0.001, kernel=sigmoid; total time=   0.0s
# [CV 5/5] END .............C=100, gamma=0.001, kernel=sigmoid; total time=   0.0s
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100], 'gamma': [1, 0.1, 0.01, 0.001],
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid']},
#              verbose=3)

# %%
grid.best_estimator_.get_params()
# Out:
# {'C': 0.1,
#  'break_ties': False,
#  'cache_size': 200,
#  'class_weight': None,
#  'coef0': 0.0,
#  'decision_function_shape': 'ovr',
#  'degree': 3,
#  'gamma': 1,
#  'kernel': 'linear',
#  'max_iter': -1,
#  'probability': False,
#  'random_state': None,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %%
from sklearn.svm import SVC
svm = SVC(C=0.1, gamma = 1, kernel = "linear")
svm.fit(x_train,y_train)

svm.score(x_test,y_test)
# Out:
# 1.0

# %%
pipe = Pipeline([('classifier' , SVC())])

# Create param grid.

param_grid = [
    {'classifier' : [LogisticRegression()],
     'classifier__penalty' : ['l1', 'l2'],
    'classifier__C' : np.linspace(1, 10, 20),
    'classifier__solver' : ['liblinear']},
    {'classifier' : [GradientBoostingClassifier()],
    'classifier__n_estimators' : list(range(10,101,10)),
     'classifier__learning_rate' : np.linspace(0.1, 10, 50)},
     {'classifier' : [GaussianNB()],'classifier__var_smoothing' :np.linspace(0.0000001, 0.001,4)},
    {'classifier' : [SVC()],
         'classifier__C' : np.linspace(0.1, 10, 20),
    'classifier__kernel' : ['linear', 'poly', 'rbf']}
    

   
]

# Create grid search object

clf = GridSearchCV(pipe, param_grid = param_grid, cv = 3, verbose=True, n_jobs=-1)

# Fit on data

best_clf = clf.fit(x_train, y_train)
# Out:
# Fitting 3 folds for each of 604 candidates, totalling 1812 fits

# %%
fig, axes = plt.subplots(nrows=data.shape[1], ncols=1, figsize=(20,13*data.shape[1]))
    col = df.bmi
    sns.countplot(x=col, data=data, hue=target, palette="seismic", ax=axes)
axes[0].legend([])
plt.show()
